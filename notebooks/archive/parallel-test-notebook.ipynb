# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib
import math
import seaborn as sns
import pandas as pd
from sympy import *
from sympy import Symbol, solveset, S, erf, log, sqrt
init_printing(use_unicode=True)

import multiprocessing as mp
from functools import partial

import scipy.optimize as optimize

from parallelnobargainFTGscript import *

# %%
#freeze_support()
crossterms = [-0.1]#[.75,1.25]#[0,-.25,.25]

for ct in crossterms:
    C_0 = np.array([[1,ct],[ct,1]])
    C_1 = np.array([[1,ct],[ct,1]])
    delta = 0.5
    r = np.array([1,1])
    thetaGs = np.linspace(0,1,21)#1.5,31)#76)
    thetaDs = np.linspace(0,1.5,31)#2.5,51)#126)
    create_results_df(C_0, C_1, r, delta,thetaGs,thetaDs, output_file_name=f'nobargaining_results_parallel_june9_crossterm_{ct}.csv')
# Out:
# Using 10 processes
# Parallel processing complete. Generated 441 results.

# %%
deltas = [.25,.5,.75]

for d in deltas:
    C_0 = np.array([[1,0],[0,1]])
    C_1 = np.array([[1,0],[0,1]])
    delta = d
    r = np.array([1,1])
    thetaGs = [0]#np.linspace(0,1.5,31)#76)
    thetaDs = np.linspace(0,1.5,151)#2.5,251)#126)
    create_results_df(C_0, C_1, r, delta,thetaGs,thetaDs, output_file_name=f'nobargaining_results_parallel_june8_delta_{d}.csv')
# Out:
# Using 10 processes
# Parallel processing complete. Generated 151 results.
# Using 10 processes
# Parallel processing complete. Generated 151 results.
# Using 10 processes
# Parallel processing complete. Generated 151 results.

# %%
np.linspace(0,2.5,51)
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 ])
